# %%
#import all necessary packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sb

# %%
data=pd.read_csv("C:\\Users\\Honey\\Downloads\\Car_DataSet.csv",encoding='ANSI')
data.head()
# Out:
#    S_number                              Name    Location  Year  \
# 0         0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1         1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2         2                      Honda Jazz V     Chennai  2011
# 3         3                 Maruti Ertiga VDI     Chennai  2012
# 4         4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage(kmpl)  \
# 0              72000       CNG       Manual      First          26.60
# 1              41000    Diesel       Manual      First          19.67
# 2              46000    Petrol       Manual      First          18.20
# 3              87000    Diesel       Manual      First          20.77
# 4              40670    Diesel    Automatic     Second          15.20
#
#    Engine(CC) Power(bhp)  Seats  New_Price  Price paint_color         type  \
# 0       998.0      58.16    5.0        NaN   1.75        blue        other
# 1      1582.0      126.2    5.0        NaN  12.50        blue  convertible
# 2      1199.0       88.7    5.0  8.61 Lakh   4.50        blue          NaN
# 3      1248.0      88.76    7.0        NaN   6.00      orange          SUV
# 4      1968.0      140.8    5.0        NaN  17.74         NaN          NaN
#
#    condition
# 0        NaN
# 1        NaN
# 2  excellent
# 3        NaN
# 4        NaN

# %%
data.drop('S_number',axis=1,inplace=True)
data.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type  Mileage(kmpl)  Engine(CC) Power(bhp)  \
# 0       CNG       Manual      First          26.60       998.0      58.16
# 1    Diesel       Manual      First          19.67      1582.0      126.2
# 2    Petrol       Manual      First          18.20      1199.0       88.7
# 3    Diesel       Manual      First          20.77      1248.0      88.76
# 4    Diesel    Automatic     Second          15.20      1968.0      140.8
#
#    Seats  New_Price  Price paint_color         type  condition
# 0    5.0        NaN   1.75        blue        other        NaN
# 1    5.0        NaN  12.50        blue  convertible        NaN
# 2    5.0  8.61 Lakh   4.50        blue          NaN  excellent
# 3    7.0        NaN   6.00      orange          SUV        NaN
# 4    5.0        NaN  17.74         NaN          NaN        NaN

# %%
data.shape
# Out:
# (6019, 16)

# %%
data_dup=data.drop_duplicates()
data_dup.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type  Mileage(kmpl)  Engine(CC) Power(bhp)  \
# 0       CNG       Manual      First          26.60       998.0      58.16
# 1    Diesel       Manual      First          19.67      1582.0      126.2
# 2    Petrol       Manual      First          18.20      1199.0       88.7
# 3    Diesel       Manual      First          20.77      1248.0      88.76
# 4    Diesel    Automatic     Second          15.20      1968.0      140.8
#
#    Seats  New_Price  Price paint_color         type  condition
# 0    5.0        NaN   1.75        blue        other        NaN
# 1    5.0        NaN  12.50        blue  convertible        NaN
# 2    5.0  8.61 Lakh   4.50        blue          NaN  excellent
# 3    7.0        NaN   6.00      orange          SUV        NaN
# 4    5.0        NaN  17.74         NaN          NaN        NaN

# %%
data_dup['Price']=data_dup['Price']*100000
data_dup.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type  Mileage(kmpl)  Engine(CC) Power(bhp)  \
# 0       CNG       Manual      First          26.60       998.0      58.16
# 1    Diesel       Manual      First          19.67      1582.0      126.2
# 2    Petrol       Manual      First          18.20      1199.0       88.7
# 3    Diesel       Manual      First          20.77      1248.0      88.76
# 4    Diesel    Automatic     Second          15.20      1968.0      140.8
#
#    Seats  New_Price      Price paint_color         type  condition
# 0    5.0        NaN   175000.0        blue        other        NaN
# 1    5.0        NaN  1250000.0        blue  convertible        NaN
# 2    5.0  8.61 Lakh   450000.0        blue          NaN  excellent
# 3    7.0        NaN   600000.0      orange          SUV        NaN
# 4    5.0        NaN  1774000.0         NaN          NaN        NaN

# %%
data_dup.dropna(axis=0,how='all',inplace=True)
data_dup.isnull().sum()
# Out:
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage(kmpl)           2
# Engine(CC)             36
# Power(bhp)             36
# Seats                  42
# New_Price            5195
# Price                   0
# paint_color          2124
# type                 1433
# condition            2565
# dtype: int64

# %%
data1=data_dup
data1.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type  Mileage(kmpl)  Engine(CC) Power(bhp)  \
# 0       CNG       Manual      First          26.60       998.0      58.16
# 1    Diesel       Manual      First          19.67      1582.0      126.2
# 2    Petrol       Manual      First          18.20      1199.0       88.7
# 3    Diesel       Manual      First          20.77      1248.0      88.76
# 4    Diesel    Automatic     Second          15.20      1968.0      140.8
#
#    Seats  New_Price      Price paint_color         type  condition
# 0    5.0        NaN   175000.0        blue        other        NaN
# 1    5.0        NaN  1250000.0        blue  convertible        NaN
# 2    5.0  8.61 Lakh   450000.0        blue          NaN  excellent
# 3    7.0        NaN   600000.0      orange          SUV        NaN
# 4    5.0        NaN  1774000.0         NaN          NaN        NaN

# %% [markdown]
# # Handle categorical variables with numerically coded values

# %%
data_dup.dtypes
# Out:
# Name                  object
# Location              object
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type             object
# Transmission          object
# Owner_Type            object
# Mileage(kmpl)        float64
# Engine(CC)           float64
# Power(bhp)            object
# Seats                float64
# New_Price             object
# Price                float64
# paint_color           object
# type                  object
# condition             object
# dtype: object

# %%
data_dup['Name_id']=pd.Categorical(data_dup.Name).codes
data_dup['Loction_id']=pd.Categorical(data_dup.Location).codes
data_dup['Fuel_Type_id']=pd.Categorical(data_dup.Fuel_Type).codes
data_dup['Transmission_id']=pd.Categorical(data_dup.Transmission).codes
data_dup['Owner_Type_id']=pd.Categorical(data_dup.Owner_Type).codes
data_dup['type_id']=pd.Categorical(data_dup.type).codes
data_dup['condition_id']=pd.Categorical(data_dup.condition).codes
data_dup.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type  Mileage(kmpl)  Engine(CC) Power(bhp)  \
# 0       CNG       Manual      First          26.60       998.0      58.16
# 1    Diesel       Manual      First          19.67      1582.0      126.2
# 2    Petrol       Manual      First          18.20      1199.0       88.7
# 3    Diesel       Manual      First          20.77      1248.0      88.76
# 4    Diesel    Automatic     Second          15.20      1968.0      140.8
#
#    ...  paint_color         type  condition Name_id Loction_id Fuel_Type_id  \
# 0  ...         blue        other        NaN    1200          9            0
# 1  ...         blue  convertible        NaN     512         10            1
# 2  ...         blue          NaN  excellent     486          2            4
# 3  ...       orange          SUV        NaN    1059          2            1
# 4  ...          NaN          NaN        NaN      23          3            1
#
#    Transmission_id  Owner_Type_id  type_id  condition_id
# 0                1              0        7            -1
# 1                1              0        2            -1
# 2                1              0       -1             0
# 3                1              0        0            -1
# 4                0              2       -1            -1
#
# [5 rows x 23 columns]

# %% [markdown]
# # Perform univariate and bivariate analysis and derive meaningful insights about the dataset

# %%
#Univariate Analysis on Categorical data
data_dup['Transmission'].value_counts().plot.bar(title='Transmission graph')
plt.grid(color='r')
plt.show()

# %%
#Bivariate Analysis used to find the relationship between two variable by analyzing the scatter plot
car_hist = data1.drop(['Name','Location','Fuel_Type','Transmission','Owner_Type','paint_color','type','condition'],axis=1)
sb.pairplot(car_hist)
plt.show()

# %% [markdown]
# # REMOVING OUTLIERS

# %%
col_names =  ['Year','Kilometers_Driven','Mileage(kmpl)','Engine(CC)','Seats','Price']

fig, ax = plt.subplots(len(col_names), figsize=(8,40))

for i, col_val in enumerate(col_names):

    sb.boxplot(y=car_data_hist[col_val], ax=ax[i])
    ax[i].set_title('Box plot - {}'.format(col_val), fontsize=10)
    ax[i].set_xlabel(col_val, fontsize=8)

plt.show()

# %%
def percentile_based_outlier(data, threshold=95):
    diff = (100 - threshold) / 2
    minval, maxval = np.percentile(data, [diff, 100 - diff])
    return (data < minval) | (data > maxval)

col_names = ['Year','Kilometers_Driven','Mileage(kmpl)','Engine(CC)','Seats','Price']
fig, ax = plt.subplots(len(col_names), figsize=(8,40))

for i, col_val in enumerate(col_names):
    x = car_data_hist[col_val][:1000]
    sb.distplot(x, ax=ax[i], rug=True, hist=False)
    outliers = x[percentile_based_outlier(x)]
    ax[i].plot(outliers, np.zeros_like(outliers), 'ro', clip_on=False)

    ax[i].set_title('Outlier detection - {}'.format(col_val), fontsize=10)
    ax[i].set_xlabel(col_val, fontsize=8)

plt.show()

# %% [markdown]
# # CORRELATION

# %%
t,c = plt.subplots(figsize=(16, 15))
corr = car_data_hist.corr()
sb.heatmap(corr,
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)
plt.show()
